# %% [markdown]
# # Objectif :
# ## Comprendre le dataset de maintenance prédictive

# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv("../data/processed/preprocessed_data.csv")
df.head()
# Out:
#          date    device  failure    metric1  metric2  metric3  metric4  \
# 0  2015-01-01  S1F01085        0  215630672       55        0       52
# 1  2015-01-01  S1F0166B        0   61370680        0        3        0
# 2  2015-01-01  S1F01E6Y        0  173295968        0        0        0
# 3  2015-01-01  S1F01JE0        0   79694024        0        0        0
# 4  2015-01-01  S1F01R2B        0  135970480        0        0        0
#
#    metric5  metric6  metric7  metric8  metric9
# 0        6   407438        0        0        7
# 1        6   403174        0        0        0
# 2       12   237394        0        0        0
# 3        6   410186        0        0        0
# 4       15   313173        0        0        3

# %%
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124493 entries, 0 to 124492
# Data columns (total 12 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   date     124493 non-null  object
#  1   device   124493 non-null  object
#  2   failure  124493 non-null  int64
#  3   metric1  124493 non-null  int64
#  4   metric2  124493 non-null  int64
#  5   metric3  124493 non-null  int64
#  6   metric4  124493 non-null  int64
#  7   metric5  124493 non-null  int64
#  8   metric6  124493 non-null  int64
#  9   metric7  124493 non-null  int64
#  10  metric8  124493 non-null  int64
#  11  metric9  124493 non-null  int64
# dtypes: int64(10), object(2)
# memory usage: 11.4+ MB
# (124493, 12)

# %% [markdown]
#  *vérifié la structure des données avec df.info(). Le dataset contient environ 124 000 observations, sans valeurs manquantes, et j’ai supprimé un doublon. Les données sont principalement numériques, ce qui facilite la modélisation*

# %%
df["failure"].value_counts()
df["failure"].value_counts(normalize=True)
# Out:
# failure
# 0    0.999149
# 1    0.000851
# Name: proportion, dtype: float64

# %% [markdown]
# *Le dataset est très déséquilibré, avec environ 99 de données normales et très peu de pannes. Cela signifie que l’accuracy n’est pas une métrique fiable, et qu’il faut privilégier des métriques comme le recall pour détecter les pannes*

# %%
df.describe()
# Out:
#              failure       metric1        metric2        metric3  \
# count  124493.000000  1.244930e+05  124493.000000  124493.000000
# mean        0.000851  1.223875e+08     159.493988       9.940977
# std         0.029167  7.045934e+07    2179.686488     185.748875
# min         0.000000  0.000000e+00       0.000000       0.000000
# 25%         0.000000  6.128346e+07       0.000000       0.000000
# 50%         0.000000  1.227971e+08       0.000000       0.000000
# 75%         0.000000  1.833091e+08       0.000000       0.000000
# max         1.000000  2.441405e+08   64968.000000   24929.000000
#
#              metric4        metric5        metric6        metric7  \
# count  124493.000000  124493.000000  124493.000000  124493.000000
# mean        1.741134      14.222719  260173.031022       0.292531
# std        22.908598      15.943082   99151.389285       7.436954
# min         0.000000       1.000000       8.000000       0.000000
# 25%         0.000000       8.000000  221452.000000       0.000000
# 50%         0.000000      10.000000  249800.000000       0.000000
# 75%         0.000000      12.000000  310266.000000       0.000000
# max      1666.000000      98.000000  689161.000000     832.000000
#
#              metric8        metric9
# count  124493.000000  124493.000000
# mean        0.292531      13.013953
# std         7.436954     275.662324
# min         0.000000       0.000000
# 25%         0.000000       0.000000
# 50%         0.000000       0.000000
# 75%         0.000000       0.000000
# max       832.000000   70000.000000

# %%
metrics = [
    "metric1", "metric2", "metric3", "metric4", "metric5",
    "metric6", "metric7", "metric8", "metric9"
]

df.groupby("failure")[metrics].mean()
# Out:
#               metric1      metric2  metric3    metric4    metric5  \
# failure
# 0        1.223835e+08   156.127931  9.94612   1.696061  14.221663
# 1        1.271755e+08  4109.433962  3.90566  54.632075  15.462264
#
#                metric6    metric7    metric8    metric9
# failure
# 0        260174.624213   0.266684   0.266684  13.005370
# 1        258303.481132  30.622642  30.622642  23.084906

# %% [markdown]
# *J’ai utilisé groupby pour séparer les machines normales et en panne, puis j’ai calculé la moyenne des métriques afin d’identifier celles qui changent le plus et peuvent être utilisées pour prédire les pannes*
# *J’ai comparé les métriques entre les machines normales et en panne. Certaines variables comme metric2, metric4, metric7 et metric8 présentent des différences très importantes, ce qui suggère qu’elles sont fortement liées aux pannes et seront utiles pour la prédiction *

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x="failure", y="metric2", data=df)
plt.show()

# %% [markdown]
# ## Les boxplots m’ont permis de comparer les métriques entre les machines normales et en panne, et d’identifier les variables les plus discriminantes.

# %%
metrics = ["metric2", "metric4", "metric7", "metric8"]

for m in metrics:
    sns.boxplot(x="failure", y=m, data=df)
    plt.title(f"{m} vs failure")
    plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("../data/processed/preprocessed_data.csv")



plt.figure(figsize=(10, 5))
plt.plot(df_sorted["date"], df_sorted["metric2"], marker="o")

plt.title("Évolution de metric2 dans le temps")
plt.xlabel("Date")
plt.ylabel("metric2")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 import pandas as pd
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 df = pd.read_csv("ton_fichier.csv")
#       5
#       6 df["date"] = pd.to_datetime(df["date"])
#       7
#
# File E:\Alternance\renault\Predictive Maintenance Systeme\.venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File E:\Alternance\renault\Predictive Maintenance Systeme\.venv\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File E:\Alternance\renault\Predictive Maintenance Systeme\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File E:\Alternance\renault\Predictive Maintenance Systeme\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File E:\Alternance\renault\Predictive Maintenance Systeme\.venv\Lib\site-packages\pandas\io\common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     921 elif isinstance(handle, str):
#     922     # Check whether the filename is to be opened in binary mode.
#     923     # Binary mode does not support 'encoding' and 'newline'.
#     924     if ioargs.encoding and "b" not in ioargs.mode:
#     925         # Encoding
# --> 926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#     929             encoding=ioargs.encoding,
#     930             errors=errors,
#     931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
#     935         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ton_fichier.csv'

# %%
df["date"] = pd.to_datetime(df["date"])

df_sorted = df.sort_values("date")

plt.plot(df_sorted["date"], df_sorted["metric2"])
plt.title("Evolution de metric2 dans le temps")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df["date"] = pd.to_datetime(df["date"])
#       2
#       3 df_sorted = df.sort_values("date")
#       4
#
# NameError: name 'pd' is not defined
